# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
for dirname, _, filenames in os.walk("brain tumor dataset"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# brain tumor dataset\Testing\glioma_tumor\image(1).jpg
# brain tumor dataset\Testing\glioma_tumor\image(10).jpg
# brain tumor dataset\Testing\glioma_tumor\image(100).jpg
# brain tumor dataset\Testing\glioma_tumor\image(11).jpg
# brain tumor dataset\Testing\glioma_tumor\image(12).jpg
# brain tumor dataset\Testing\glioma_tumor\image(13).jpg
# brain tumor dataset\Testing\glioma_tumor\image(14).jpg
# brain tumor dataset\Testing\glioma_tumor\image(15).jpg
# brain tumor dataset\Testing\glioma_tumor\image(16).jpg
# brain tumor dataset\Testing\glioma_tumor\image(17).jpg
# brain tumor dataset\Testing\glioma_tumor\image(18).jpg
# brain tumor dataset\Testing\glioma_tumor\image(19).jpg
# brain tumor dataset\Testing\glioma_tumor\image(2).jpg
# brain tumor dataset\Testing\glioma_tumor\image(20).jpg
# brain tumor dataset\Testing\glioma_tumor\image(21).jpg
# brain tumor dataset\Testing\glioma_tumor\image(22).jpg
# brain tumor dataset\Testing\glioma_tumor\image(23).jpg
# brain tumor dataset\Testing\glioma_tumor\image(24).jpg
# brain tumor dataset\Testing\glioma_tumor\image(25).jpg
# brain tumor dataset\Testing\glioma_tumor\image(26).jpg
# brain tumor dataset\Testing\glioma_tumor\image(27).jpg
# brain tumor dataset\Testing\glioma_tumor\image(28).jpg
# brain tumor dataset\Testing\glioma_tumor\image(29).jpg
# brain tumor dataset\Testing\glioma_tumor\image(3).jpg
# brain tumor dataset\Testing\glioma_tumor\image(30).jpg
# brain tumor dataset\Testing\glioma_tumor\image(31).jpg
# brain tumor dataset\Testing\glioma_tumor\image(32).jpg
# brain tumor dataset\Testing\glioma_tumor\image(33).jpg
# brain tumor dataset\Testing\glioma_tumor\image(34).jpg
# brain tumor dataset\Testing\glioma_tumor\image(35).jpg
# brain tumor dataset\Testing\glioma_tumor\image(36).jpg
# brain tumor dataset\Testing\glioma_tumor\image(37).jpg
# brain tumor dataset\Testing\glioma_tumor\image(38).jpg
# brain tumor dataset\Testing\glioma_tumor\image(39).jpg
# brain tumor dataset\Testing\glioma_tumor\image(4).jpg
# brain tumor dataset\Testing\glioma_tumor\image(40).jpg
# brain tumor dataset\Testing\glioma_tumor\image(41).jpg
# brain tumor dataset\Testing\glioma_tumor\image(42).jpg
# brain tumor dataset\Testing\glioma_tumor\image(43).jpg
# brain tumor dataset\Testing\glioma_tumor\image(44).jpg
# brain tumor dataset\Testing\glioma_tumor\image(45).jpg
# brain tumor dataset\Testing\glioma_tumor\image(46).jpg
# brain tumor dataset\Testing\glioma_tumor\image(47).jpg
# brain tumor dataset\Testing\glioma_tumor\image(48).jpg
# brain tumor dataset\Testing\glioma_tumor\image(49).jpg
# brain tumor dataset\Testing\glioma_tumor\image(5).jpg
# brain tumor dataset\Testing\glioma_tumor\image(50).jpg
# brain tumor dataset\Testing\glioma_tumor\image(51).jpg
# brain tumor dataset\Testing\glioma_tumor\image(52).jpg
# brain tumor dataset\Testing\glioma_tumor\image(53).jpg
# brain tumor dataset\Testing\glioma_tumor\image(54).jpg
# brain tumor dataset\Testing\glioma_tumor\image(55).jpg
# brain tumor dataset\Testing\glioma_tumor\image(56).jpg
# brain tumor dataset\Testing\glioma_tumor\image(57).jpg
# brain tumor dataset\Testing\glioma_tumor\image(58).jpg
# brain tumor dataset\Testing\glioma_tumor\image(59).jpg
# brain tumor dataset\Testing\glioma_tumor\image(6).jpg
# brain tumor dataset\Testing\glioma_tumor\image(60).jpg
# brain tumor dataset\Testing\glioma_tumor\image(61).jpg
# brain tumor dataset\Testing\glioma_tumor\image(62).jpg
# brain tumor dataset\Testing\glioma_tumor\image(63).jpg
# brain tumor dataset\Testing\glioma_tumor\image(64).jpg
# brain tumor dataset\Testing\glioma_tumor\image(65).jpg
# brain tumor dataset\Testing\glioma_tumor\image(66).jpg
# brain tumor dataset\Testing\glioma_tumor\image(67).jpg
# brain tumor dataset\Testing\glioma_tumor\image(68).jpg
# brain tumor dataset\Testing\glioma_tumor\image(69).jpg
# brain tumor dataset\Testing\glioma_tumor\image(7).jpg
# brain tumor dataset\Testing\glioma_tumor\image(70).jpg
# brain tumor dataset\Testing\glioma_tumor\image(71).jpg
# brain tumor dataset\Testing\glioma_tumor\image(72).jpg
# brain tumor dataset\Testing\glioma_tumor\image(73).jpg
# brain tumor dataset\Testing\glioma_tumor\image(74).jpg
# brain tumor dataset\Testing\glioma_tumor\image(75).jpg
# brain tumor dataset\Testing\glioma_tumor\image(76).jpg
# brain tumor dataset\Testing\glioma_tumor\image(77).jpg
# brain tumor dataset\Testing\glioma_tumor\image(78).jpg
# brain tumor dataset\Testing\glioma_tumor\image(79).jpg
# brain tumor dataset\Testing\glioma_tumor\image(8).jpg
# brain tumor dataset\Testing\glioma_tumor\image(80).jpg
# brain tumor dataset\Testing\glioma_tumor\image(81).jpg
# brain tumor dataset\Testing\glioma_tumor\image(82).jpg
# brain tumor dataset\Testing\glioma_tumor\image(83).jpg
# brain tumor dataset\Testing\glioma_tumor\image(84).jpg
# brain tumor dataset\Testing\glioma_tumor\image(85).jpg
# brain tumor dataset\Testing\glioma_tumor\image(86).jpg
# brain tumor dataset\Testing\glioma_tumor\image(87).jpg
# brain tumor dataset\Testing\glioma_tumor\image(88).jpg
# brain tumor dataset\Testing\glioma_tumor\image(89).jpg
# brain tumor dataset\Testing\glioma_tumor\image(9).jpg
# brain tumor dataset\Testing\glioma_tumor\image(90).jpg
# brain tumor dataset\Testing\glioma_tumor\image(91).jpg
# brain tumor dataset\Testing\glioma_tumor\image(92).jpg
# brain tumor dataset\Testing\glioma_tumor\image(93).jpg
# brain tumor dataset\Testing\glioma_tumor\image(94).jpg
# brain tumor dataset\Testing\glioma_tumor\image(95).jpg
# brain tumor dataset\Testing\glioma_tumor\image(97).jpg
# brain tumor dataset\Testing\glioma_tumor\image(98).jpg
# brain tumor dataset\Testing\glioma_tumor\image(99).jpg
# brain tumor dataset\Testing\glioma_tumor\image.jpg
# brain tumor dataset\Testing\meningioma_tumor\image(1).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(10).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(100).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(102).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(106).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(107).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(109).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(11).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(112).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(113).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(118).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(12).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(120).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(121).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(123).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(124).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(125).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(126).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(127).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(13).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(14).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(15).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(16).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(17).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(18).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(19).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(2).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(20).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(21).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(22).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(23).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(24).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(25).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(26).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(27).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(28).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(29).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(3).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(30).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(31).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(32).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(33).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(34).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(35).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(36).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(37).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(38).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(39).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(4).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(40).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(41).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(42).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(43).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(44).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(45).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(46).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(47).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(48).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(49).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(5).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(50).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(51).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(52).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(53).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(54).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(55).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(56).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(57).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(58).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(59).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(6).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(60).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(61).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(62).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(63).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(64).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(65).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(66).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(67).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(68).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(69).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(7).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(70).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(71).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(72).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(73).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(74).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(75).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(76).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(77).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(78).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(79).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(8).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(80).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(81).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(82).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(83).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(84).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(85).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(86).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(87).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(88).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(89).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(9).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(90).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(91).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(92).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(93).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(94).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(95).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(96).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(97).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(98).jpg
# brain tumor dataset\Testing\meningioma_tumor\image(99).jpg
# brain tumor dataset\Testing\meningioma_tumor\image.jpg
# brain tumor dataset\Testing\no_tumor\image(1).jpg
# brain tumor dataset\Testing\no_tumor\image(10).jpg
# brain tumor dataset\Testing\no_tumor\image(100).jpg
# brain tumor dataset\Testing\no_tumor\image(101).jpg
# brain tumor dataset\Testing\no_tumor\image(102).jpg
# brain tumor dataset\Testing\no_tumor\image(103).jpg
# brain tumor dataset\Testing\no_tumor\image(104).jpg
# brain tumor dataset\Testing\no_tumor\image(11).jpg
# brain tumor dataset\Testing\no_tumor\image(12).jpg
# brain tumor dataset\Testing\no_tumor\image(13).jpg
# brain tumor dataset\Testing\no_tumor\image(14).jpg
# brain tumor dataset\Testing\no_tumor\image(15).jpg
# brain tumor dataset\Testing\no_tumor\image(16).jpg
# brain tumor dataset\Testing\no_tumor\image(17).jpg
# brain tumor dataset\Testing\no_tumor\image(18).jpg
# brain tumor dataset\Testing\no_tumor\image(19).jpg
# brain tumor dataset\Testing\no_tumor\image(2).jpg
# brain tumor dataset\Testing\no_tumor\image(20).jpg
# brain tumor dataset\Testing\no_tumor\image(21).jpg
# brain tumor dataset\Testing\no_tumor\image(22).jpg
# brain tumor dataset\Testing\no_tumor\image(23).jpg
# brain tumor dataset\Testing\no_tumor\image(24).jpg
# brain tumor dataset\Testing\no_tumor\image(25).jpg
# brain tumor dataset\Testing\no_tumor\image(26).jpg
# brain tumor dataset\Testing\no_tumor\image(27).jpg
# brain tumor dataset\Testing\no_tumor\image(28).jpg
# brain tumor dataset\Testing\no_tumor\image(29).jpg
# brain tumor dataset\Testing\no_tumor\image(3).jpg
# brain tumor dataset\Testing\no_tumor\image(30).jpg
# brain tumor dataset\Testing\no_tumor\image(31).jpg
# brain tumor dataset\Testing\no_tumor\image(32).jpg
# brain tumor dataset\Testing\no_tumor\image(33).jpg
# brain tumor dataset\Testing\no_tumor\image(34).jpg
# brain tumor dataset\Testing\no_tumor\image(35).jpg
# brain tumor dataset\Testing\no_tumor\image(36).jpg
# brain tumor dataset\Testing\no_tumor\image(37).jpg
# brain tumor dataset\Testing\no_tumor\image(38).jpg
# brain tumor dataset\Testing\no_tumor\image(39).jpg
# brain tumor dataset\Testing\no_tumor\image(4).jpg
# brain tumor dataset\Testing\no_tumor\image(40).jpg
# brain tumor dataset\Testing\no_tumor\image(41).jpg
# brain tumor dataset\Testing\no_tumor\image(42).jpg
# brain tumor dataset\Testing\no_tumor\image(43).jpg
# brain tumor dataset\Testing\no_tumor\image(44).jpg
# brain tumor dataset\Testing\no_tumor\image(45).jpg
# brain tumor dataset\Testing\no_tumor\image(46).jpg
# brain tumor dataset\Testing\no_tumor\image(47).jpg
# brain tumor dataset\Testing\no_tumor\image(48).jpg
# brain tumor dataset\Testing\no_tumor\image(49).jpg
# brain tumor dataset\Testing\no_tumor\image(5).jpg
# brain tumor dataset\Testing\no_tumor\image(50).jpg
# brain tumor dataset\Testing\no_tumor\image(51).jpg
# brain tumor dataset\Testing\no_tumor\image(52).jpg
# brain tumor dataset\Testing\no_tumor\image(53).jpg
# brain tumor dataset\Testing\no_tumor\image(54).jpg
# brain tumor dataset\Testing\no_tumor\image(55).jpg
# brain tumor dataset\Testing\no_tumor\image(56).jpg
# brain tumor dataset\Testing\no_tumor\image(57).jpg
# brain tumor dataset\Testing\no_tumor\image(58).jpg
# brain tumor dataset\Testing\no_tumor\image(59).jpg
# brain tumor dataset\Testing\no_tumor\image(6).jpg
# brain tumor dataset\Testing\no_tumor\image(60).jpg
# brain tumor dataset\Testing\no_tumor\image(61).jpg
# brain tumor dataset\Testing\no_tumor\image(62).jpg
# brain tumor dataset\Testing\no_tumor\image(63).jpg
# brain tumor dataset\Testing\no_tumor\image(64).jpg
# brain tumor dataset\Testing\no_tumor\image(65).jpg
# brain tumor dataset\Testing\no_tumor\image(66).jpg
# brain tumor dataset\Testing\no_tumor\image(67).jpg
# brain tumor dataset\Testing\no_tumor\image(68).jpg
# brain tumor dataset\Testing\no_tumor\image(69).jpg
# brain tumor dataset\Testing\no_tumor\image(7).jpg
# brain tumor dataset\Testing\no_tumor\image(70).jpg
# brain tumor dataset\Testing\no_tumor\image(71).jpg
# brain tumor dataset\Testing\no_tumor\image(72).jpg
# brain tumor dataset\Testing\no_tumor\image(73).jpg
# brain tumor dataset\Testing\no_tumor\image(74).jpg
# brain tumor dataset\Testing\no_tumor\image(75).jpg
# brain tumor dataset\Testing\no_tumor\image(76).jpg
# brain tumor dataset\Testing\no_tumor\image(77).jpg
# brain tumor dataset\Testing\no_tumor\image(78).jpg
# brain tumor dataset\Testing\no_tumor\image(79).jpg
# brain tumor dataset\Testing\no_tumor\image(8).jpg
# brain tumor dataset\Testing\no_tumor\image(80).jpg
# brain tumor dataset\Testing\no_tumor\image(81).jpg
# brain tumor dataset\Testing\no_tumor\image(82).jpg
# brain tumor dataset\Testing\no_tumor\image(83).jpg
# brain tumor dataset\Testing\no_tumor\image(84).jpg
# brain tumor dataset\Testing\no_tumor\image(85).jpg
# brain tumor dataset\Testing\no_tumor\image(86).jpg
# brain tumor dataset\Testing\no_tumor\image(87).jpg
# brain tumor dataset\Testing\no_tumor\image(88).jpg
# brain tumor dataset\Testing\no_tumor\image(89).jpg
# brain tumor dataset\Testing\no_tumor\image(9).jpg
# brain tumor dataset\Testing\no_tumor\image(90).jpg
# brain tumor dataset\Testing\no_tumor\image(91).jpg
# brain tumor dataset\Testing\no_tumor\image(92).jpg
# brain tumor dataset\Testing\no_tumor\image(93).jpg
# brain tumor dataset\Testing\no_tumor\image(94).jpg
# brain tumor dataset\Testing\no_tumor\image(95).jpg
# brain tumor dataset\Testing\no_tumor\image(96).jpg
# brain tumor dataset\Testing\no_tumor\image(97).jpg
# brain tumor dataset\Testing\no_tumor\image(98).jpg
# brain tumor dataset\Testing\no_tumor\image(99).jpg
# brain tumor dataset\Testing\no_tumor\image.jpg
# brain tumor dataset\Testing\pituitary_tumor\image(1).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(10).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(11).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(13).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(15).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(18).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(19).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(2).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(20).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(21).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(22).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(23).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(27).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(28).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(3).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(30).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(31).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(34).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(35).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(36).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(37).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(38).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(41).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(42).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(43).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(44).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(45).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(46).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(47).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(48).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(49).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(5).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(51).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(52).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(53).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(54).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(55).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(56).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(57).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(6).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(60).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(61).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(63).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(64).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(65).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(66).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(67).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(68).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(69).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(7).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(70).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(73).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(76).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(77).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(78).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(79).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(8).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(81).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(82).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(85).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(86).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(87).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(88).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(89).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(90).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(91).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(92).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(93).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(94).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(95).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(96).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(97).jpg
# brain tumor dataset\Testing\pituitary_tumor\image(98).jpg
# brain tumor dataset\Testing\pituitary_tumor\image.jpg
# brain tumor dataset\Training\glioma_tumor\gg (1).jpg
# brain tumor dataset\Training\glioma_tumor\gg (10).jpg
# brain tumor dataset\Training\glioma_tumor\gg (100).jpg
# brain tumor dataset\Training\glioma_tumor\gg (101).jpg
# brain tumor dataset\Training\glioma_tumor\gg (102).jpg
# brain tumor dataset\Training\glioma_tumor\gg (103).jpg
# brain tumor dataset\Training\glioma_tumor\gg (104).jpg
# brain tumor dataset\Training\glioma_tumor\gg (105).jpg
# brain tumor dataset\Training\glioma_tumor\gg (106).jpg
# brain tumor dataset\Training\glioma_tumor\gg (107).jpg
# brain tumor dataset\Training\glioma_tumor\gg (108).jpg
# brain tumor dataset\Training\glioma_tumor\gg (109).jpg
# brain tumor dataset\Training\glioma_tumor\gg (11).jpg
# brain tumor dataset\Training\glioma_tumor\gg (110).jpg
# brain tumor dataset\Training\glioma_tumor\gg (111).jpg
# brain tumor dataset\Training\glioma_tumor\gg (112).jpg
# brain tumor dataset\Training\glioma_tumor\gg (113).jpg
# brain tumor dataset\Training\glioma_tumor\gg (114).jpg
# brain tumor dataset\Training\glioma_tumor\gg (115).jpg
# brain tumor dataset\Training\glioma_tumor\gg (116).jpg
# brain tumor dataset\Training\glioma_tumor\gg (117).jpg
# brain tumor dataset\Training\glioma_tumor\gg (118).jpg
# brain tumor dataset\Training\glioma_tumor\gg (119).jpg
# brain tumor dataset\Training\glioma_tumor\gg (12).jpg
# brain tumor dataset\Training\glioma_tumor\gg (120).jpg
# brain tumor dataset\Training\glioma_tumor\gg (121).jpg
# brain tumor dataset\Training\glioma_tumor\gg (122).jpg
# brain tumor dataset\Training\glioma_tumor\gg (123).jpg
# brain tumor dataset\Training\glioma_tumor\gg (124).jpg
# brain tumor dataset\Training\glioma_tumor\gg (125).jpg
# brain tumor dataset\Training\glioma_tumor\gg (126).jpg
# brain tumor dataset\Training\glioma_tumor\gg (127).jpg
# brain tumor dataset\Training\glioma_tumor\gg (128).jpg
# brain tumor dataset\Training\glioma_tumor\gg (129).jpg
# brain tumor dataset\Training\glioma_tumor\gg (13).jpg
# brain tumor dataset\Training\glioma_tumor\gg (130).jpg
# brain tumor dataset\Training\glioma_tumor\gg (131).jpg
# brain tumor dataset\Training\glioma_tumor\gg (132).jpg
# brain tumor dataset\Training\glioma_tumor\gg (133).jpg
# brain tumor dataset\Training\glioma_tumor\gg (134).jpg
# brain tumor dataset\Training\glioma_tumor\gg (135).jpg
# brain tumor dataset\Training\glioma_tumor\gg (136).jpg
# brain tumor dataset\Training\glioma_tumor\gg (137).jpg
# brain tumor dataset\Training\glioma_tumor\gg (138).jpg
# brain tumor dataset\Training\glioma_tumor\gg (139).jpg
# brain tumor dataset\Training\glioma_tumor\gg (14).jpg
# brain tumor dataset\Training\glioma_tumor\gg (140).jpg
# brain tumor dataset\Training\glioma_tumor\gg (141).jpg
# brain tumor dataset\Training\glioma_tumor\gg (142).jpg
# brain tumor dataset\Training\glioma_tumor\gg (143).jpg
# brain tumor dataset\Training\glioma_tumor\gg (144).jpg
# brain tumor dataset\Training\glioma_tumor\gg (145).jpg
# brain tumor dataset\Training\glioma_tumor\gg (146).jpg
# brain tumor dataset\Training\glioma_tumor\gg (147).jpg
# brain tumor dataset\Training\glioma_tumor\gg (148).jpg
# brain tumor dataset\Training\glioma_tumor\gg (149).jpg
# brain tumor dataset\Training\glioma_tumor\gg (15).jpg
# brain tumor dataset\Training\glioma_tumor\gg (150).jpg
# brain tumor dataset\Training\glioma_tumor\gg (151).jpg
# brain tumor dataset\Training\glioma_tumor\gg (152).jpg
# brain tumor dataset\Training\glioma_tumor\gg (153).jpg
# brain tumor dataset\Training\glioma_tumor\gg (154).jpg
# brain tumor dataset\Training\glioma_tumor\gg (155).jpg
# brain tumor dataset\Training\glioma_tumor\gg (156).jpg
# brain tumor dataset\Training\glioma_tumor\gg (157).jpg
# brain tumor dataset\Training\glioma_tumor\gg (158).jpg
# brain tumor dataset\Training\glioma_tumor\gg (159).jpg
# brain tumor dataset\Training\glioma_tumor\gg (16).jpg
# brain tumor dataset\Training\glioma_tumor\gg (160).jpg
# brain tumor dataset\Training\glioma_tumor\gg (161).jpg
# brain tumor dataset\Training\glioma_tumor\gg (162).jpg
# brain tumor dataset\Training\glioma_tumor\gg (163).jpg
# brain tumor dataset\Training\glioma_tumor\gg (164).jpg
# brain tumor dataset\Training\glioma_tumor\gg (165).jpg
# brain tumor dataset\Training\glioma_tumor\gg (166).jpg
# brain tumor dataset\Training\glioma_tumor\gg (167).jpg
# brain tumor dataset\Training\glioma_tumor\gg (168).jpg
# brain tumor dataset\Training\glioma_tumor\gg (169).jpg
# brain tumor dataset\Training\glioma_tumor\gg (17).jpg
# brain tumor dataset\Training\glioma_tumor\gg (170).jpg
# brain tumor dataset\Training\glioma_tumor\gg (171).jpg
# brain tumor dataset\Training\glioma_tumor\gg (172).jpg
# brain tumor dataset\Training\glioma_tumor\gg (173).jpg
# brain tumor dataset\Training\glioma_tumor\gg (174).jpg
# brain tumor dataset\Training\glioma_tumor\gg (175).jpg
# brain tumor dataset\Training\glioma_tumor\gg (176).jpg
# brain tumor dataset\Training\glioma_tumor\gg (177).jpg
# brain tumor dataset\Training\glioma_tumor\gg (178).jpg
# brain tumor dataset\Training\glioma_tumor\gg (179).jpg
# brain tumor dataset\Training\glioma_tumor\gg (18).jpg
# brain tumor dataset\Training\glioma_tumor\gg (180).jpg
# brain tumor dataset\Training\glioma_tumor\gg (181).jpg
# brain tumor dataset\Training\glioma_tumor\gg (182).jpg
# brain tumor dataset\Training\glioma_tumor\gg (183).jpg
# brain tumor dataset\Training\glioma_tumor\gg (184).jpg
# brain tumor dataset\Training\glioma_tumor\gg (185).jpg
# brain tumor dataset\Training\glioma_tumor\gg (186).jpg
# brain tumor dataset\Training\glioma_tumor\gg (187).jpg
# brain tumor dataset\Training\glioma_tumor\gg (188).jpg
# brain tumor dataset\Training\glioma_tumor\gg (189).jpg
# brain tumor dataset\Training\glioma_tumor\gg (19).jpg
# brain tumor dataset\Training\glioma_tumor\gg (190).jpg
# brain tumor dataset\Training\glioma_tumor\gg (191).jpg
# brain tumor dataset\Training\glioma_tumor\gg (192).jpg
# brain tumor dataset\Training\glioma_tumor\gg (193).jpg
# brain tumor dataset\Training\glioma_tumor\gg (194).jpg
# brain tumor dataset\Training\glioma_tumor\gg (195).jpg
# brain tumor dataset\Training\glioma_tumor\gg (196).jpg
# brain tumor dataset\Training\glioma_tumor\gg (197).jpg
# brain tumor dataset\Training\glioma_tumor\gg (198).jpg
# brain tumor dataset\Training\glioma_tumor\gg (199).jpg
# brain tumor dataset\Training\glioma_tumor\gg (2).jpg
# brain tumor dataset\Training\glioma_tumor\gg (20).jpg
# brain tumor dataset\Training\glioma_tumor\gg (200).jpg
# brain tumor dataset\Training\glioma_tumor\gg (201).jpg
# brain tumor dataset\Training\glioma_tumor\gg (202).jpg
# brain tumor dataset\Training\glioma_tumor\gg (203).jpg
# brain tumor dataset\Training\glioma_tumor\gg (204).jpg
# brain tumor dataset\Training\glioma_tumor\gg (205).jpg
# brain tumor dataset\Training\glioma_tumor\gg (206).jpg
# brain tumor dataset\Training\glioma_tumor\gg (207).jpg
# brain tumor dataset\Training\glioma_tumor\gg (208).jpg
# brain tumor dataset\Training\glioma_tumor\gg (209).jpg
# brain tumor dataset\Training\glioma_tumor\gg (21).jpg
# brain tumor dataset\Training\glioma_tumor\gg (210).jpg
# brain tumor dataset\Training\glioma_tumor\gg (211).jpg
# brain tumor dataset\Training\glioma_tumor\gg (212).jpg
# brain tumor dataset\Training\glioma_tumor\gg (213).jpg
# brain tumor dataset\Training\glioma_tumor\gg (214).jpg
# brain tumor dataset\Training\glioma_tumor\gg (215).jpg
# brain tumor dataset\Training\glioma_tumor\gg (216).jpg
# brain tumor dataset\Training\glioma_tumor\gg (217).jpg
# brain tumor dataset\Training\glioma_tumor\gg (218).jpg
# brain tumor dataset\Training\glioma_tumor\gg (219).jpg
# brain tumor dataset\Training\glioma_tumor\gg (22).jpg
# brain tumor dataset\Training\glioma_tumor\gg (220).jpg
# brain tumor dataset\Training\glioma_tumor\gg (221).jpg
# brain tumor dataset\Training\glioma_tumor\gg (222).jpg
# brain tumor dataset\Training\glioma_tumor\gg (223).jpg
# brain tumor dataset\Training\glioma_tumor\gg (224).jpg
# brain tumor dataset\Training\glioma_tumor\gg (225).jpg
# brain tumor dataset\Training\glioma_tumor\gg (226).jpg
# brain tumor dataset\Training\glioma_tumor\gg (227).jpg
# brain tumor dataset\Training\glioma_tumor\gg (228).jpg
# brain tumor dataset\Training\glioma_tumor\gg (229).jpg
# brain tumor dataset\Training\glioma_tumor\gg (23).jpg
# brain tumor dataset\Training\glioma_tumor\gg (230).jpg
# brain tumor dataset\Training\glioma_tumor\gg (231).jpg
# brain tumor dataset\Training\glioma_tumor\gg (232).jpg
# brain tumor dataset\Training\glioma_tumor\gg (233).jpg
# brain tumor dataset\Training\glioma_tumor\gg (234).jpg
# brain tumor dataset\Training\glioma_tumor\gg (235).jpg
# brain tumor dataset\Training\glioma_tumor\gg (236).jpg
# brain tumor dataset\Training\glioma_tumor\gg (237).jpg
# brain tumor dataset\Training\glioma_tumor\gg (238).jpg
# brain tumor dataset\Training\glioma_tumor\gg (239).jpg
# brain tumor dataset\Training\glioma_tumor\gg (24).jpg
# brain tumor dataset\Training\glioma_tumor\gg (240).jpg
# brain tumor dataset\Training\glioma_tumor\gg (241).jpg
# brain tumor dataset\Training\glioma_tumor\gg (242).jpg
# brain tumor dataset\Training\glioma_tumor\gg (243).jpg
# brain tumor dataset\Training\glioma_tumor\gg (244).jpg
# brain tumor dataset\Training\glioma_tumor\gg (245).jpg
# brain tumor dataset\Training\glioma_tumor\gg (246).jpg
# brain tumor dataset\Training\glioma_tumor\gg (247).jpg
# brain tumor dataset\Training\glioma_tumor\gg (248).jpg
# brain tumor dataset\Training\glioma_tumor\gg (249).jpg
# brain tumor dataset\Training\glioma_tumor\gg (25).jpg
# brain tumor dataset\Training\glioma_tumor\gg (250).jpg
# brain tumor dataset\Training\glioma_tumor\gg (251).jpg
# brain tumor dataset\Training\glioma_tumor\gg (252).jpg
# brain tumor dataset\Training\glioma_tumor\gg (253).jpg
# brain tumor dataset\Training\glioma_tumor\gg (254).jpg
# brain tumor dataset\Training\glioma_tumor\gg (255).jpg
# brain tumor dataset\Training\glioma_tumor\gg (256).jpg
# brain tumor dataset\Training\glioma_tumor\gg (257).jpg
# brain tumor dataset\Training\glioma_tumor\gg (258).jpg
# brain tumor dataset\Training\glioma_tumor\gg (259).jpg
# brain tumor dataset\Training\glioma_tumor\gg (26).jpg
# brain tumor dataset\Training\glioma_tumor\gg (260).jpg
# brain tumor dataset\Training\glioma_tumor\gg (261).jpg
# brain tumor dataset\Training\glioma_tumor\gg (262).jpg
# brain tumor dataset\Training\glioma_tumor\gg (263).jpg
# brain tumor dataset\Training\glioma_tumor\gg (264).jpg
# brain tumor dataset\Training\glioma_tumor\gg (265).jpg
# brain tumor dataset\Training\glioma_tumor\gg (266).jpg
# brain tumor dataset\Training\glioma_tumor\gg (267).jpg
# brain tumor dataset\Training\glioma_tumor\gg (268).jpg
# brain tumor dataset\Training\glioma_tumor\gg (269).jpg
# brain tumor dataset\Training\glioma_tumor\gg (27).jpg
# brain tumor dataset\Training\glioma_tumor\gg (270).jpg
# brain tumor dataset\Training\glioma_tumor\gg (271).jpg
# brain tumor dataset\Training\glioma_tumor\gg (272).jpg
# brain tumor dataset\Training\glioma_tumor\gg (273).jpg
# brain tumor dataset\Training\glioma_tumor\gg (274).jpg
# brain tumor dataset\Training\glioma_tumor\gg (275).jpg
# brain tumor dataset\Training\glioma_tumor\gg (276).jpg
# brain tumor dataset\Training\glioma_tumor\gg (277).jpg
# brain tumor dataset\Training\glioma_tumor\gg (278).jpg
# brain tumor dataset\Training\glioma_tumor\gg (279).jpg
# brain tumor dataset\Training\glioma_tumor\gg (28).jpg
# brain tumor dataset\Training\glioma_tumor\gg (280).jpg
# brain tumor dataset\Training\glioma_tumor\gg (281).jpg
# brain tumor dataset\Training\glioma_tumor\gg (282).jpg
# brain tumor dataset\Training\glioma_tumor\gg (283).jpg
# brain tumor dataset\Training\glioma_tumor\gg (284).jpg
# brain tumor dataset\Training\glioma_tumor\gg (285).jpg
# brain tumor dataset\Training\glioma_tumor\gg (286).jpg
# brain tumor dataset\Training\glioma_tumor\gg (287).jpg
# brain tumor dataset\Training\glioma_tumor\gg (288).jpg
# brain tumor dataset\Training\glioma_tumor\gg (289).jpg
# brain tumor dataset\Training\glioma_tumor\gg (29).jpg
# brain tumor dataset\Training\glioma_tumor\gg (290).jpg
# brain tumor dataset\Training\glioma_tumor\gg (291).jpg
# brain tumor dataset\Training\glioma_tumor\gg (292).jpg
# brain tumor dataset\Training\glioma_tumor\gg (293).jpg
# brain tumor dataset\Training\glioma_tumor\gg (294).jpg
# brain tumor dataset\Training\glioma_tumor\gg (295).jpg
# brain tumor dataset\Training\glioma_tumor\gg (296).jpg
# brain tumor dataset\Training\glioma_tumor\gg (297).jpg
# brain tumor dataset\Training\glioma_tumor\gg (298).jpg
# brain tumor dataset\Training\glioma_tumor\gg (299).jpg
# brain tumor dataset\Training\glioma_tumor\gg (3).jpg
# brain tumor dataset\Training\glioma_tumor\gg (30).jpg
# brain tumor dataset\Training\glioma_tumor\gg (300).jpg
# brain tumor dataset\Training\glioma_tumor\gg (301).jpg
# brain tumor dataset\Training\glioma_tumor\gg (302).jpg
# brain tumor dataset\Training\glioma_tumor\gg (303).jpg
# brain tumor dataset\Training\glioma_tumor\gg (304).jpg
# brain tumor dataset\Training\glioma_tumor\gg (305).jpg
# brain tumor dataset\Training\glioma_tumor\gg (306).jpg
# brain tumor dataset\Training\glioma_tumor\gg (307).jpg
# brain tumor dataset\Training\glioma_tumor\gg (308).jpg
# brain tumor dataset\Training\glioma_tumor\gg (309).jpg
# brain tumor dataset\Training\glioma_tumor\gg (31).jpg
# brain tumor dataset\Training\glioma_tumor\gg (310).jpg
# brain tumor dataset\Training\glioma_tumor\gg (311).jpg
# brain tumor dataset\Training\glioma_tumor\gg (312).jpg
# brain tumor dataset\Training\glioma_tumor\gg (313).jpg
# brain tumor dataset\Training\glioma_tumor\gg (314).jpg
# brain tumor dataset\Training\glioma_tumor\gg (315).jpg
# brain tumor dataset\Training\glioma_tumor\gg (316).jpg
# brain tumor dataset\Training\glioma_tumor\gg (317).jpg
# brain tumor dataset\Training\glioma_tumor\gg (318).jpg
# brain tumor dataset\Training\glioma_tumor\gg (319).jpg
# brain tumor dataset\Training\glioma_tumor\gg (32).jpg
# brain tumor dataset\Training\glioma_tumor\gg (320).jpg
# brain tumor dataset\Training\glioma_tumor\gg (321).jpg
# brain tumor dataset\Training\glioma_tumor\gg (322).jpg
# brain tumor dataset\Training\glioma_tumor\gg (323).jpg
# brain tumor dataset\Training\glioma_tumor\gg (324).jpg
# brain tumor dataset\Training\glioma_tumor\gg (325).jpg
# brain tumor dataset\Training\glioma_tumor\gg (326).jpg
# brain tumor dataset\Training\glioma_tumor\gg (327).jpg
# brain tumor dataset\Training\glioma_tumor\gg (328).jpg
# brain tumor dataset\Training\glioma_tumor\gg (329).jpg
# brain tumor dataset\Training\glioma_tumor\gg (33).jpg
# brain tumor dataset\Training\glioma_tumor\gg (330).jpg
# brain tumor dataset\Training\glioma_tumor\gg (331).jpg
# brain tumor dataset\Training\glioma_tumor\gg (332).jpg
# brain tumor dataset\Training\glioma_tumor\gg (333).jpg
# brain tumor dataset\Training\glioma_tumor\gg (334).jpg
# brain tumor dataset\Training\glioma_tumor\gg (335).jpg
# brain tumor dataset\Training\glioma_tumor\gg (336).jpg
# brain tumor dataset\Training\glioma_tumor\gg (337).jpg
# brain tumor dataset\Training\glioma_tumor\gg (338).jpg
# brain tumor dataset\Training\glioma_tumor\gg (339).jpg
# brain tumor dataset\Training\glioma_tumor\gg (34).jpg
# brain tumor dataset\Training\glioma_tumor\gg (340).jpg
# brain tumor dataset\Training\glioma_tumor\gg (341).jpg
# brain tumor dataset\Training\glioma_tumor\gg (342).jpg
# brain tumor dataset\Training\glioma_tumor\gg (343).jpg
# brain tumor dataset\Training\glioma_tumor\gg (344).jpg
# brain tumor dataset\Training\glioma_tumor\gg (345).jpg
# brain tumor dataset\Training\glioma_tumor\gg (346).jpg
# brain tumor dataset\Training\glioma_tumor\gg (347).jpg
# brain tumor dataset\Training\glioma_tumor\gg (348).jpg
# brain tumor dataset\Training\glioma_tumor\gg (349).jpg
# brain tumor dataset\Training\glioma_tumor\gg (35).jpg
# brain tumor dataset\Training\glioma_tumor\gg (350).jpg
# brain tumor dataset\Training\glioma_tumor\gg (351).jpg
# brain tumor dataset\Training\glioma_tumor\gg (352).jpg
# brain tumor dataset\Training\glioma_tumor\gg (353).jpg
# brain tumor dataset\Training\glioma_tumor\gg (354).jpg
# brain tumor dataset\Training\glioma_tumor\gg (355).jpg
# brain tumor dataset\Training\glioma_tumor\gg (356).jpg
# brain tumor dataset\Training\glioma_tumor\gg (357).jpg
# brain tumor dataset\Training\glioma_tumor\gg (358).jpg
# brain tumor dataset\Training\glioma_tumor\gg (359).jpg
# brain tumor dataset\Training\glioma_tumor\gg (36).jpg
# brain tumor dataset\Training\glioma_tumor\gg (360).jpg
# brain tumor dataset\Training\glioma_tumor\gg (361).jpg
# brain tumor dataset\Training\glioma_tumor\gg (362).jpg
# brain tumor dataset\Training\glioma_tumor\gg (363).jpg
# brain tumor dataset\Training\glioma_tumor\gg (364).jpg
# brain tumor dataset\Training\glioma_tumor\gg (365).jpg
# brain tumor dataset\Training\glioma_tumor\gg (366).jpg
# brain tumor dataset\Training\glioma_tumor\gg (367).jpg
# brain tumor dataset\Training\glioma_tumor\gg (368).jpg
# brain tumor dataset\Training\glioma_tumor\gg (369).jpg
# brain tumor dataset\Training\glioma_tumor\gg (37).jpg
# brain tumor dataset\Training\glioma_tumor\gg (370).jpg
# brain tumor dataset\Training\glioma_tumor\gg (371).jpg
# brain tumor dataset\Training\glioma_tumor\gg (372).jpg
# brain tumor dataset\Training\glioma_tumor\gg (373).jpg
# brain tumor dataset\Training\glioma_tumor\gg (374).jpg
# brain tumor dataset\Training\glioma_tumor\gg (375).jpg
# brain tumor dataset\Training\glioma_tumor\gg (376).jpg
# brain tumor dataset\Training\glioma_tumor\gg (377).jpg
# brain tumor dataset\Training\glioma_tumor\gg (378).jpg
# brain tumor dataset\Training\glioma_tumor\gg (379).jpg
# brain tumor dataset\Training\glioma_tumor\gg (38).jpg
# brain tumor dataset\Training\glioma_tumor\gg (380).jpg
# brain tumor dataset\Training\glioma_tumor\gg (381).jpg
# brain tumor dataset\Training\glioma_tumor\gg (382).jpg
# brain tumor dataset\Training\glioma_tumor\gg (383).jpg
# brain tumor dataset\Training\glioma_tumor\gg (384).jpg
# brain tumor dataset\Training\glioma_tumor\gg (385).jpg
# brain tumor dataset\Training\glioma_tumor\gg (386).jpg
# brain tumor dataset\Training\glioma_tumor\gg (387).jpg
# brain tumor dataset\Training\glioma_tumor\gg (388).jpg
# brain tumor dataset\Training\glioma_tumor\gg (389).jpg
# brain tumor dataset\Training\glioma_tumor\gg (39).jpg
# brain tumor dataset\Training\glioma_tumor\gg (390).jpg
# brain tumor dataset\Training\glioma_tumor\gg (391).jpg
# brain tumor dataset\Training\glioma_tumor\gg (392).jpg
# brain tumor dataset\Training\glioma_tumor\gg (393).jpg
# brain tumor dataset\Training\glioma_tumor\gg (394).jpg
# brain tumor dataset\Training\glioma_tumor\gg (395).jpg
# brain tumor dataset\Training\glioma_tumor\gg (396).jpg
# brain tumor dataset\Training\glioma_tumor\gg (397).jpg
# brain tumor dataset\Training\glioma_tumor\gg (398).jpg
# brain tumor dataset\Training\glioma_tumor\gg (399).jpg
# brain tumor dataset\Training\glioma_tumor\gg (4).jpg
# brain tumor dataset\Training\glioma_tumor\gg (40).jpg
# brain tumor dataset\Training\glioma_tumor\gg (400).jpg
# brain tumor dataset\Training\glioma_tumor\gg (401).jpg
# brain tumor dataset\Training\glioma_tumor\gg (402).jpg
# brain tumor dataset\Training\glioma_tumor\gg (403).jpg
# brain tumor dataset\Training\glioma_tumor\gg (404).jpg
# brain tumor dataset\Training\glioma_tumor\gg (405).jpg
# brain tumor dataset\Training\glioma_tumor\gg (406).jpg
# brain tumor dataset\Training\glioma_tumor\gg (407).jpg
# brain tumor dataset\Training\glioma_tumor\gg (408).jpg
# brain tumor dataset\Training\glioma_tumor\gg (409).jpg
# brain tumor dataset\Training\glioma_tumor\gg (41).jpg
# brain tumor dataset\Training\glioma_tumor\gg (410).jpg
# brain tumor dataset\Training\glioma_tumor\gg (411).jpg
# brain tumor dataset\Training\glioma_tumor\gg (412).jpg
# brain tumor dataset\Training\glioma_tumor\gg (413).jpg
# brain tumor dataset\Training\glioma_tumor\gg (414).jpg
# brain tumor dataset\Training\glioma_tumor\gg (415).jpg
# brain tumor dataset\Training\glioma_tumor\gg (416).jpg
# brain tumor dataset\Training\glioma_tumor\gg (417).jpg
# brain tumor dataset\Training\glioma_tumor\gg (418).jpg
# brain tumor dataset\Training\glioma_tumor\gg (419).jpg
# brain tumor dataset\Training\glioma_tumor\gg (42).jpg
# brain tumor dataset\Training\glioma_tumor\gg (420).jpg
# brain tumor dataset\Training\glioma_tumor\gg (421).jpg
# brain tumor dataset\Training\glioma_tumor\gg (422).jpg
# brain tumor dataset\Training\glioma_tumor\gg (423).jpg
# brain tumor dataset\Training\glioma_tumor\gg (424).jpg
# brain tumor dataset\Training\glioma_tumor\gg (425).jpg
# brain tumor dataset\Training\glioma_tumor\gg (426).jpg
# brain tumor dataset\Training\glioma_tumor\gg (427).jpg
# brain tumor dataset\Training\glioma_tumor\gg (428).jpg
# brain tumor dataset\Training\glioma_tumor\gg (429).jpg
# brain tumor dataset\Training\glioma_tumor\gg (43).jpg
# brain tumor dataset\Training\glioma_tumor\gg (430).jpg
# brain tumor dataset\Training\glioma_tumor\gg (431).jpg
# brain tumor dataset\Training\glioma_tumor\gg (432).jpg
# brain tumor dataset\Training\glioma_tumor\gg (433).jpg
# brain tumor dataset\Training\glioma_tumor\gg (434).jpg
# brain tumor dataset\Training\glioma_tumor\gg (435).jpg
# brain tumor dataset\Training\glioma_tumor\gg (436).jpg
# brain tumor dataset\Training\glioma_tumor\gg (437).jpg
# brain tumor dataset\Training\glioma_tumor\gg (438).jpg
# brain tumor dataset\Training\glioma_tumor\gg (439).jpg
# brain tumor dataset\Training\glioma_tumor\gg (44).jpg
# brain tumor dataset\Training\glioma_tumor\gg (440).jpg
# brain tumor dataset\Training\glioma_tumor\gg (441).jpg
# brain tumor dataset\Training\glioma_tumor\gg (442).jpg
# brain tumor dataset\Training\glioma_tumor\gg (443).jpg
# brain tumor dataset\Training\glioma_tumor\gg (444).jpg
# brain tumor dataset\Training\glioma_tumor\gg (445).jpg
# brain tumor dataset\Training\glioma_tumor\gg (446).jpg
# brain tumor dataset\Training\glioma_tumor\gg (447).jpg
# brain tumor dataset\Training\glioma_tumor\gg (448).jpg
# brain tumor dataset\Training\glioma_tumor\gg (449).jpg
# brain tumor dataset\Training\glioma_tumor\gg (45).jpg
# brain tumor dataset\Training\glioma_tumor\gg (450).jpg
# brain tumor dataset\Training\glioma_tumor\gg (451).jpg
# brain tumor dataset\Training\glioma_tumor\gg (452).jpg
# brain tumor dataset\Training\glioma_tumor\gg (453).jpg
# brain tumor dataset\Training\glioma_tumor\gg (454).jpg
# brain tumor dataset\Training\glioma_tumor\gg (455).jpg
# brain tumor dataset\Training\glioma_tumor\gg (456).jpg
# brain tumor dataset\Training\glioma_tumor\gg (457).jpg
# brain tumor dataset\Training\glioma_tumor\gg (458).jpg
# brain tumor dataset\Training\glioma_tumor\gg (459).jpg
# brain tumor dataset\Training\glioma_tumor\gg (46).jpg
# brain tumor dataset\Training\glioma_tumor\gg (460).jpg
# brain tumor dataset\Training\glioma_tumor\gg (461).jpg
# brain tumor dataset\Training\glioma_tumor\gg (462).jpg
# brain tumor dataset\Training\glioma_tumor\gg (463).jpg
# brain tumor dataset\Training\glioma_tumor\gg (464).jpg
# brain tumor dataset\Training\glioma_tumor\gg (465).jpg
# brain tumor dataset\Training\glioma_tumor\gg (466).jpg
# brain tumor dataset\Training\glioma_tumor\gg (467).jpg
# brain tumor dataset\Training\glioma_tumor\gg (468).jpg
# brain tumor dataset\Training\glioma_tumor\gg (469).jpg
# brain tumor dataset\Training\glioma_tumor\gg (47).jpg
# brain tumor dataset\Training\glioma_tumor\gg (470).jpg
# brain tumor dataset\Training\glioma_tumor\gg (471).jpg
# brain tumor dataset\Training\glioma_tumor\gg (472).jpg
# brain tumor dataset\Training\glioma_tumor\gg (473).jpg
# brain tumor dataset\Training\glioma_tumor\gg (474).jpg
# brain tumor dataset\Training\glioma_tumor\gg (475).jpg
# brain tumor dataset\Training\glioma_tumor\gg (476).jpg
# brain tumor dataset\Training\glioma_tumor\gg (477).jpg
# brain tumor dataset\Training\glioma_tumor\gg (478).jpg
# brain tumor dataset\Training\glioma_tumor\gg (479).jpg
# brain tumor dataset\Training\glioma_tumor\gg (48).jpg
# brain tumor dataset\Training\glioma_tumor\gg (480).jpg
# brain tumor dataset\Training\glioma_tumor\gg (481).jpg
# brain tumor dataset\Training\glioma_tumor\gg (482).jpg
# brain tumor dataset\Training\glioma_tumor\gg (483).jpg
# brain tumor dataset\Training\glioma_tumor\gg (484).jpg
# brain tumor dataset\Training\glioma_tumor\gg (485).jpg
# brain tumor dataset\Training\glioma_tumor\gg (486).jpg
# brain tumor dataset\Training\glioma_tumor\gg (487).jpg
# brain tumor dataset\Training\glioma_tumor\gg (488).jpg
# brain tumor dataset\Training\glioma_tumor\gg (489).jpg
# brain tumor dataset\Training\glioma_tumor\gg (49).jpg
# brain tumor dataset\Training\glioma_tumor\gg (490).jpg
# brain tumor dataset\Training\glioma_tumor\gg (491).jpg
# brain tumor dataset\Training\glioma_tumor\gg (492).jpg
# brain tumor dataset\Training\glioma_tumor\gg (493).jpg
# brain tumor dataset\Training\glioma_tumor\gg (494).jpg
# brain tumor dataset\Training\glioma_tumor\gg (495).jpg
# brain tumor dataset\Training\glioma_tumor\gg (496).jpg
# brain tumor dataset\Training\glioma_tumor\gg (497).jpg
# brain tumor dataset\Training\glioma_tumor\gg (498).jpg
# brain tumor dataset\Training\glioma_tumor\gg (499).jpg
# brain tumor dataset\Training\glioma_tumor\gg (5).jpg
# brain tumor dataset\Training\glioma_tumor\gg (50).jpg
# brain tumor dataset\Training\glioma_tumor\gg (500).jpg
# brain tumor dataset\Training\glioma_tumor\gg (501).jpg
# brain tumor dataset\Training\glioma_tumor\gg (502).jpg
# brain tumor dataset\Training\glioma_tumor\gg (503).jpg
# brain tumor dataset\Training\glioma_tumor\gg (504).jpg
# brain tumor dataset\Training\glioma_tumor\gg (505).jpg
# brain tumor dataset\Training\glioma_tumor\gg (506).jpg
# brain tumor dataset\Training\glioma_tumor\gg (507).jpg
# brain tumor dataset\Training\glioma_tumor\gg (508).jpg
# brain tumor dataset\Training\glioma_tumor\gg (509).jpg
# brain tumor dataset\Training\glioma_tumor\gg (51).jpg
# brain tumor dataset\Training\glioma_tumor\gg (510).jpg
# brain tumor dataset\Training\glioma_tumor\gg (511).jpg
# brain tumor dataset\Training\glioma_tumor\gg (512).jpg
# brain tumor dataset\Training\glioma_tumor\gg (513).jpg
# brain tumor dataset\Training\glioma_tumor\gg (514).jpg
# brain tumor dataset\Training\glioma_tumor\gg (515).jpg
# brain tumor dataset\Training\glioma_tumor\gg (516).jpg
# brain tumor dataset\Training\glioma_tumor\gg (517).jpg
# brain tumor dataset\Training\glioma_tumor\gg (518).jpg
# brain tumor dataset\Training\glioma_tumor\gg (519).jpg
# brain tumor dataset\Training\glioma_tumor\gg (52).jpg
# brain tumor dataset\Training\glioma_tumor\gg (520).jpg
# brain tumor dataset\Training\glioma_tumor\gg (521).jpg
# brain tumor dataset\Training\glioma_tumor\gg (522).jpg
# brain tumor dataset\Training\glioma_tumor\gg (523).jpg
# brain tumor dataset\Training\glioma_tumor\gg (524).jpg
# brain tumor dataset\Training\glioma_tumor\gg (525).jpg
# brain tumor dataset\Training\glioma_tumor\gg (526).jpg
# ...
# brain tumor dataset\Training\pituitary_tumor\p (591).jpg
# brain tumor dataset\Training\pituitary_tumor\p (592).jpg
# brain tumor dataset\Training\pituitary_tumor\p (593).jpg
# brain tumor dataset\Training\pituitary_tumor\p (594).jpg
# brain tumor dataset\Training\pituitary_tumor\p (595).jpg
# brain tumor dataset\Training\pituitary_tumor\p (596).jpg
# brain tumor dataset\Training\pituitary_tumor\p (597).jpg
# brain tumor dataset\Training\pituitary_tumor\p (598).jpg
# brain tumor dataset\Training\pituitary_tumor\p (599).jpg
# brain tumor dataset\Training\pituitary_tumor\p (6).jpg
# brain tumor dataset\Training\pituitary_tumor\p (60).jpg
# brain tumor dataset\Training\pituitary_tumor\p (600).jpg
# brain tumor dataset\Training\pituitary_tumor\p (601).jpg
# brain tumor dataset\Training\pituitary_tumor\p (602).jpg
# brain tumor dataset\Training\pituitary_tumor\p (603).jpg
# brain tumor dataset\Training\pituitary_tumor\p (604).jpg
# brain tumor dataset\Training\pituitary_tumor\p (605).jpg
# brain tumor dataset\Training\pituitary_tumor\p (606).jpg
# brain tumor dataset\Training\pituitary_tumor\p (607).jpg
# brain tumor dataset\Training\pituitary_tumor\p (608).jpg
# brain tumor dataset\Training\pituitary_tumor\p (609).jpg
# brain tumor dataset\Training\pituitary_tumor\p (61).jpg
# brain tumor dataset\Training\pituitary_tumor\p (610).jpg
# brain tumor dataset\Training\pituitary_tumor\p (611).jpg
# brain tumor dataset\Training\pituitary_tumor\p (612).jpg
# brain tumor dataset\Training\pituitary_tumor\p (613).jpg
# brain tumor dataset\Training\pituitary_tumor\p (614).jpg
# brain tumor dataset\Training\pituitary_tumor\p (615).jpg
# brain tumor dataset\Training\pituitary_tumor\p (616).jpg
# brain tumor dataset\Training\pituitary_tumor\p (617).jpg
# brain tumor dataset\Training\pituitary_tumor\p (618).jpg
# brain tumor dataset\Training\pituitary_tumor\p (619).jpg
# brain tumor dataset\Training\pituitary_tumor\p (62).jpg
# brain tumor dataset\Training\pituitary_tumor\p (620).jpg
# brain tumor dataset\Training\pituitary_tumor\p (621).jpg
# brain tumor dataset\Training\pituitary_tumor\p (622).jpg
# brain tumor dataset\Training\pituitary_tumor\p (623).jpg
# brain tumor dataset\Training\pituitary_tumor\p (624).jpg
# brain tumor dataset\Training\pituitary_tumor\p (625).jpg
# brain tumor dataset\Training\pituitary_tumor\p (626).jpg
# brain tumor dataset\Training\pituitary_tumor\p (627).jpg
# brain tumor dataset\Training\pituitary_tumor\p (628).jpg
# brain tumor dataset\Training\pituitary_tumor\p (629).jpg
# brain tumor dataset\Training\pituitary_tumor\p (63).jpg
# brain tumor dataset\Training\pituitary_tumor\p (630).jpg
# brain tumor dataset\Training\pituitary_tumor\p (631).jpg
# brain tumor dataset\Training\pituitary_tumor\p (632).jpg
# brain tumor dataset\Training\pituitary_tumor\p (633).jpg
# brain tumor dataset\Training\pituitary_tumor\p (634).jpg
# brain tumor dataset\Training\pituitary_tumor\p (635).jpg
# brain tumor dataset\Training\pituitary_tumor\p (636).jpg
# brain tumor dataset\Training\pituitary_tumor\p (637).jpg
# brain tumor dataset\Training\pituitary_tumor\p (638).jpg
# brain tumor dataset\Training\pituitary_tumor\p (639).jpg
# brain tumor dataset\Training\pituitary_tumor\p (64).jpg
# brain tumor dataset\Training\pituitary_tumor\p (640).jpg
# brain tumor dataset\Training\pituitary_tumor\p (641).jpg
# brain tumor dataset\Training\pituitary_tumor\p (642).jpg
# brain tumor dataset\Training\pituitary_tumor\p (643).jpg
# brain tumor dataset\Training\pituitary_tumor\p (644).jpg
# brain tumor dataset\Training\pituitary_tumor\p (645).jpg
# brain tumor dataset\Training\pituitary_tumor\p (646).jpg
# brain tumor dataset\Training\pituitary_tumor\p (647).jpg
# brain tumor dataset\Training\pituitary_tumor\p (648).jpg
# brain tumor dataset\Training\pituitary_tumor\p (649).jpg
# brain tumor dataset\Training\pituitary_tumor\p (65).jpg
# brain tumor dataset\Training\pituitary_tumor\p (650).jpg
# brain tumor dataset\Training\pituitary_tumor\p (651).jpg
# brain tumor dataset\Training\pituitary_tumor\p (652).jpg
# brain tumor dataset\Training\pituitary_tumor\p (653).jpg
# brain tumor dataset\Training\pituitary_tumor\p (654).jpg
# brain tumor dataset\Training\pituitary_tumor\p (655).jpg
# brain tumor dataset\Training\pituitary_tumor\p (656).jpg
# brain tumor dataset\Training\pituitary_tumor\p (657).jpg
# brain tumor dataset\Training\pituitary_tumor\p (658).jpg
# brain tumor dataset\Training\pituitary_tumor\p (659).jpg
# brain tumor dataset\Training\pituitary_tumor\p (66).jpg
# brain tumor dataset\Training\pituitary_tumor\p (660).jpg
# brain tumor dataset\Training\pituitary_tumor\p (661).jpg
# brain tumor dataset\Training\pituitary_tumor\p (662).jpg
# brain tumor dataset\Training\pituitary_tumor\p (663).jpg
# brain tumor dataset\Training\pituitary_tumor\p (664).jpg
# brain tumor dataset\Training\pituitary_tumor\p (665).jpg
# brain tumor dataset\Training\pituitary_tumor\p (666).jpg
# brain tumor dataset\Training\pituitary_tumor\p (667).jpg
# brain tumor dataset\Training\pituitary_tumor\p (668).jpg
# brain tumor dataset\Training\pituitary_tumor\p (669).jpg
# brain tumor dataset\Training\pituitary_tumor\p (67).jpg
# brain tumor dataset\Training\pituitary_tumor\p (670).jpg
# brain tumor dataset\Training\pituitary_tumor\p (671).jpg
# brain tumor dataset\Training\pituitary_tumor\p (672).jpg
# brain tumor dataset\Training\pituitary_tumor\p (673).jpg
# brain tumor dataset\Training\pituitary_tumor\p (674).jpg
# brain tumor dataset\Training\pituitary_tumor\p (675).jpg
# brain tumor dataset\Training\pituitary_tumor\p (676).jpg
# brain tumor dataset\Training\pituitary_tumor\p (677).jpg
# brain tumor dataset\Training\pituitary_tumor\p (678).jpg
# brain tumor dataset\Training\pituitary_tumor\p (679).jpg
# brain tumor dataset\Training\pituitary_tumor\p (68).jpg
# brain tumor dataset\Training\pituitary_tumor\p (680).jpg
# brain tumor dataset\Training\pituitary_tumor\p (681).jpg
# brain tumor dataset\Training\pituitary_tumor\p (682).jpg
# brain tumor dataset\Training\pituitary_tumor\p (683).jpg
# brain tumor dataset\Training\pituitary_tumor\p (684).jpg
# brain tumor dataset\Training\pituitary_tumor\p (685).jpg
# brain tumor dataset\Training\pituitary_tumor\p (686).jpg
# brain tumor dataset\Training\pituitary_tumor\p (687).jpg
# brain tumor dataset\Training\pituitary_tumor\p (688).jpg
# brain tumor dataset\Training\pituitary_tumor\p (689).jpg
# brain tumor dataset\Training\pituitary_tumor\p (69).jpg
# brain tumor dataset\Training\pituitary_tumor\p (690).jpg
# brain tumor dataset\Training\pituitary_tumor\p (691).jpg
# brain tumor dataset\Training\pituitary_tumor\p (692).jpg
# brain tumor dataset\Training\pituitary_tumor\p (693).jpg
# brain tumor dataset\Training\pituitary_tumor\p (694).jpg
# brain tumor dataset\Training\pituitary_tumor\p (695).jpg
# brain tumor dataset\Training\pituitary_tumor\p (696).jpg
# brain tumor dataset\Training\pituitary_tumor\p (697).jpg
# brain tumor dataset\Training\pituitary_tumor\p (698).jpg
# brain tumor dataset\Training\pituitary_tumor\p (699).jpg
# brain tumor dataset\Training\pituitary_tumor\p (7).jpg
# brain tumor dataset\Training\pituitary_tumor\p (70).jpg
# brain tumor dataset\Training\pituitary_tumor\p (700).jpg
# brain tumor dataset\Training\pituitary_tumor\p (701).jpg
# brain tumor dataset\Training\pituitary_tumor\p (702).jpg
# brain tumor dataset\Training\pituitary_tumor\p (703).jpg
# brain tumor dataset\Training\pituitary_tumor\p (704).jpg
# brain tumor dataset\Training\pituitary_tumor\p (705).jpg
# brain tumor dataset\Training\pituitary_tumor\p (706).jpg
# brain tumor dataset\Training\pituitary_tumor\p (707).jpg
# brain tumor dataset\Training\pituitary_tumor\p (708).jpg
# brain tumor dataset\Training\pituitary_tumor\p (709).jpg
# brain tumor dataset\Training\pituitary_tumor\p (71).jpg
# brain tumor dataset\Training\pituitary_tumor\p (710).jpg
# brain tumor dataset\Training\pituitary_tumor\p (711).jpg
# brain tumor dataset\Training\pituitary_tumor\p (712).jpg
# brain tumor dataset\Training\pituitary_tumor\p (713).jpg
# brain tumor dataset\Training\pituitary_tumor\p (714).jpg
# brain tumor dataset\Training\pituitary_tumor\p (715).jpg
# brain tumor dataset\Training\pituitary_tumor\p (716).jpg
# brain tumor dataset\Training\pituitary_tumor\p (717).jpg
# brain tumor dataset\Training\pituitary_tumor\p (718).jpg
# brain tumor dataset\Training\pituitary_tumor\p (719).jpg
# brain tumor dataset\Training\pituitary_tumor\p (72).jpg
# brain tumor dataset\Training\pituitary_tumor\p (720).jpg
# brain tumor dataset\Training\pituitary_tumor\p (721).jpg
# brain tumor dataset\Training\pituitary_tumor\p (722).jpg
# brain tumor dataset\Training\pituitary_tumor\p (723).jpg
# brain tumor dataset\Training\pituitary_tumor\p (724).jpg
# brain tumor dataset\Training\pituitary_tumor\p (725).jpg
# brain tumor dataset\Training\pituitary_tumor\p (726).jpg
# brain tumor dataset\Training\pituitary_tumor\p (727).jpg
# brain tumor dataset\Training\pituitary_tumor\p (728).jpg
# brain tumor dataset\Training\pituitary_tumor\p (729).jpg
# brain tumor dataset\Training\pituitary_tumor\p (73).jpg
# brain tumor dataset\Training\pituitary_tumor\p (730).jpg
# brain tumor dataset\Training\pituitary_tumor\p (731).jpg
# brain tumor dataset\Training\pituitary_tumor\p (732).jpg
# brain tumor dataset\Training\pituitary_tumor\p (733).jpg
# brain tumor dataset\Training\pituitary_tumor\p (734).jpg
# brain tumor dataset\Training\pituitary_tumor\p (735).jpg
# brain tumor dataset\Training\pituitary_tumor\p (736).jpg
# brain tumor dataset\Training\pituitary_tumor\p (737).jpg
# brain tumor dataset\Training\pituitary_tumor\p (738).jpg
# brain tumor dataset\Training\pituitary_tumor\p (739).jpg
# brain tumor dataset\Training\pituitary_tumor\p (74).jpg
# brain tumor dataset\Training\pituitary_tumor\p (740).jpg
# brain tumor dataset\Training\pituitary_tumor\p (741).jpg
# brain tumor dataset\Training\pituitary_tumor\p (742).jpg
# brain tumor dataset\Training\pituitary_tumor\p (743).jpg
# brain tumor dataset\Training\pituitary_tumor\p (744).jpg
# brain tumor dataset\Training\pituitary_tumor\p (745).jpg
# brain tumor dataset\Training\pituitary_tumor\p (746).jpg
# brain tumor dataset\Training\pituitary_tumor\p (747).jpg
# brain tumor dataset\Training\pituitary_tumor\p (748).jpg
# brain tumor dataset\Training\pituitary_tumor\p (749).jpg
# brain tumor dataset\Training\pituitary_tumor\p (75).jpg
# brain tumor dataset\Training\pituitary_tumor\p (750).jpg
# brain tumor dataset\Training\pituitary_tumor\p (751).jpg
# brain tumor dataset\Training\pituitary_tumor\p (752).jpg
# brain tumor dataset\Training\pituitary_tumor\p (753).jpg
# brain tumor dataset\Training\pituitary_tumor\p (754).jpg
# brain tumor dataset\Training\pituitary_tumor\p (755).jpg
# brain tumor dataset\Training\pituitary_tumor\p (756).jpg
# brain tumor dataset\Training\pituitary_tumor\p (757).jpg
# brain tumor dataset\Training\pituitary_tumor\p (758).jpg
# brain tumor dataset\Training\pituitary_tumor\p (759).jpg
# brain tumor dataset\Training\pituitary_tumor\p (76).jpg
# brain tumor dataset\Training\pituitary_tumor\p (760).jpg
# brain tumor dataset\Training\pituitary_tumor\p (761).jpg
# brain tumor dataset\Training\pituitary_tumor\p (762).jpg
# brain tumor dataset\Training\pituitary_tumor\p (763).jpg
# brain tumor dataset\Training\pituitary_tumor\p (764).jpg
# brain tumor dataset\Training\pituitary_tumor\p (765).jpg
# brain tumor dataset\Training\pituitary_tumor\p (766).jpg
# brain tumor dataset\Training\pituitary_tumor\p (767).jpg
# brain tumor dataset\Training\pituitary_tumor\p (768).jpg
# brain tumor dataset\Training\pituitary_tumor\p (769).jpg
# brain tumor dataset\Training\pituitary_tumor\p (77).jpg
# brain tumor dataset\Training\pituitary_tumor\p (770).jpg
# brain tumor dataset\Training\pituitary_tumor\p (771).jpg
# brain tumor dataset\Training\pituitary_tumor\p (772).jpg
# brain tumor dataset\Training\pituitary_tumor\p (773).jpg
# brain tumor dataset\Training\pituitary_tumor\p (774).jpg
# brain tumor dataset\Training\pituitary_tumor\p (775).jpg
# brain tumor dataset\Training\pituitary_tumor\p (776).jpg
# brain tumor dataset\Training\pituitary_tumor\p (777).jpg
# brain tumor dataset\Training\pituitary_tumor\p (778).jpg
# brain tumor dataset\Training\pituitary_tumor\p (779).jpg
# brain tumor dataset\Training\pituitary_tumor\p (78).jpg
# brain tumor dataset\Training\pituitary_tumor\p (780).jpg
# brain tumor dataset\Training\pituitary_tumor\p (781).jpg
# brain tumor dataset\Training\pituitary_tumor\p (782).jpg
# brain tumor dataset\Training\pituitary_tumor\p (783).jpg
# brain tumor dataset\Training\pituitary_tumor\p (784).jpg
# brain tumor dataset\Training\pituitary_tumor\p (785).jpg
# brain tumor dataset\Training\pituitary_tumor\p (786).jpg
# brain tumor dataset\Training\pituitary_tumor\p (787).jpg
# brain tumor dataset\Training\pituitary_tumor\p (788).jpg
# brain tumor dataset\Training\pituitary_tumor\p (789).jpg
# brain tumor dataset\Training\pituitary_tumor\p (79).jpg
# brain tumor dataset\Training\pituitary_tumor\p (790).jpg
# brain tumor dataset\Training\pituitary_tumor\p (791).jpg
# brain tumor dataset\Training\pituitary_tumor\p (792).jpg
# brain tumor dataset\Training\pituitary_tumor\p (793).jpg
# brain tumor dataset\Training\pituitary_tumor\p (794).jpg
# brain tumor dataset\Training\pituitary_tumor\p (795).jpg
# brain tumor dataset\Training\pituitary_tumor\p (796).jpg
# brain tumor dataset\Training\pituitary_tumor\p (797).jpg
# brain tumor dataset\Training\pituitary_tumor\p (798).jpg
# brain tumor dataset\Training\pituitary_tumor\p (799).jpg
# brain tumor dataset\Training\pituitary_tumor\p (8).jpg
# brain tumor dataset\Training\pituitary_tumor\p (80).jpg
# brain tumor dataset\Training\pituitary_tumor\p (800).jpg
# brain tumor dataset\Training\pituitary_tumor\p (801).jpg
# brain tumor dataset\Training\pituitary_tumor\p (802).jpg
# brain tumor dataset\Training\pituitary_tumor\p (803).jpg
# brain tumor dataset\Training\pituitary_tumor\p (804).jpg
# brain tumor dataset\Training\pituitary_tumor\p (805).jpg
# brain tumor dataset\Training\pituitary_tumor\p (806).jpg
# brain tumor dataset\Training\pituitary_tumor\p (807).jpg
# brain tumor dataset\Training\pituitary_tumor\p (808).jpg
# brain tumor dataset\Training\pituitary_tumor\p (809).jpg
# brain tumor dataset\Training\pituitary_tumor\p (81).jpg
# brain tumor dataset\Training\pituitary_tumor\p (810).jpg
# brain tumor dataset\Training\pituitary_tumor\p (811).jpg
# brain tumor dataset\Training\pituitary_tumor\p (812).jpg
# brain tumor dataset\Training\pituitary_tumor\p (813).jpg
# brain tumor dataset\Training\pituitary_tumor\p (814).jpg
# brain tumor dataset\Training\pituitary_tumor\p (815).jpg
# brain tumor dataset\Training\pituitary_tumor\p (816).jpg
# brain tumor dataset\Training\pituitary_tumor\p (817).jpg
# brain tumor dataset\Training\pituitary_tumor\p (818).jpg
# brain tumor dataset\Training\pituitary_tumor\p (819).jpg
# brain tumor dataset\Training\pituitary_tumor\p (82).jpg
# brain tumor dataset\Training\pituitary_tumor\p (820).jpg
# brain tumor dataset\Training\pituitary_tumor\p (821).jpg
# brain tumor dataset\Training\pituitary_tumor\p (822).jpg
# brain tumor dataset\Training\pituitary_tumor\p (823).jpg
# brain tumor dataset\Training\pituitary_tumor\p (824).jpg
# brain tumor dataset\Training\pituitary_tumor\p (825).jpg
# brain tumor dataset\Training\pituitary_tumor\p (826).jpg
# brain tumor dataset\Training\pituitary_tumor\p (827).jpg
# brain tumor dataset\Training\pituitary_tumor\p (83).jpg
# brain tumor dataset\Training\pituitary_tumor\p (84).jpg
# brain tumor dataset\Training\pituitary_tumor\p (85).jpg
# brain tumor dataset\Training\pituitary_tumor\p (86).jpg
# brain tumor dataset\Training\pituitary_tumor\p (87).jpg
# brain tumor dataset\Training\pituitary_tumor\p (88).jpg
# brain tumor dataset\Training\pituitary_tumor\p (89).jpg
# brain tumor dataset\Training\pituitary_tumor\p (9).jpg
# brain tumor dataset\Training\pituitary_tumor\p (90).jpg
# brain tumor dataset\Training\pituitary_tumor\p (91).jpg
# brain tumor dataset\Training\pituitary_tumor\p (92).jpg
# brain tumor dataset\Training\pituitary_tumor\p (93).jpg
# brain tumor dataset\Training\pituitary_tumor\p (94).jpg
# brain tumor dataset\Training\pituitary_tumor\p (95).jpg
# brain tumor dataset\Training\pituitary_tumor\p (96).jpg
# brain tumor dataset\Training\pituitary_tumor\p (97).jpg
# brain tumor dataset\Training\pituitary_tumor\p (98).jpg
# brain tumor dataset\Training\pituitary_tumor\p (99).jpg

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join("brain tumor dataset","Training",i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join("brain tumor dataset","Testing",i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 826/826 [00:08<00:00, 94.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 395/395 [00:04<00:00, 94.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 822/822 [00:07<00:00, 107.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 827/827 [00:09<00:00, 90.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 113.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 105/105 [00:00<00:00, 143.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 115/115 [00:00<00:00, 129.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 74/74 [00:01<00:00, 46.05it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
effnet = ResNet50(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 156, 156, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 75, 75, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 75, 75, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 75, 75, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 77, 77, 64)           0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 38, 38, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 38, 38, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 38, 38, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 38, 38, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 38, 38, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 38, 38, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 38, 38, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 38, 38, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 38, 38, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 38, 38, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 38, 38, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 38, 38, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 38, 38, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 38, 38, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 38, 38, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 38, 38, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 38, 38, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 38, 38, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 38, 38, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 38, 38, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 38, 38, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 38, 38, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 38, 38, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 19, 19, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 19, 19, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 19, 19, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 19, 19, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 19, 19, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 19, 19, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 19, 19, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 19, 19, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 19, 19, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 19, 19, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 19, 19, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 19, 19, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 19, 19, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 19, 19, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 19, 19, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 19, 19, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 19, 19, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 19, 19, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 19, 19, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 19, 19, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 19, 19, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 19, 19, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 19, 19, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 19, 19, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 19, 19, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 19, 19, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 19, 19, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 19, 19, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 10, 10, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#  conv4_block1_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 10, 10, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 10, 10, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 10, 10, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 10, 10, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 10, 10, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 10, 10, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 10, 10, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 10, 10, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 10, 10, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 10, 10, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 10, 10, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 10, 10, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 10, 10, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 5, 5, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 5, 5, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 5, 5, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 5, 5, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 5, 5, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 5, 5, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 5, 5, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 5, 5, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 5, 5, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 5, 5, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 5, 5, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 5, 5, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 5, 5, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 5, 5, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 5, 5, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#  conv5_block3_1_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 5, 5, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 5, 5, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 5, 5, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 5, 5, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 5, 5, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 5, 5, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 5, 5, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    8196      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 23595908 (90.01 MB)
# Trainable params: 23542788 (89.81 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs={}):
        print("call")
        if(logs.get('accuracy')>.99):
          print("\nReached %2.2f%% accuracy,so stopping training !!" %(99))
          self.model.stop_training=True
callbacks=myCallback()

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =2, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/2
# 67/83 [=======================>......] - ETA: 3:14 - loss: 0.7489 - accuracy: 0.7537

# %%
filterwarnings('ignore')

epochs = [i for i in range(12)]
fig, ax = plt.subplots(1,2,figsize=(10,5))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
model.save('braintumor')
